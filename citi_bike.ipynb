# %%
import pandas as pd

# %%
csv = "Resources/202301-citibike-tripdata.csv"
citi_bike_df = pd.read_csv(csv)
citi_bike_df
# Out:
# C:\Users\yaber\AppData\Local\Temp\ipykernel_12364\2762137292.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citi_bike_df = pd.read_csv(csv)
#                   ride_id  rideable_type           started_at  \
# 0        4A86C1475DCCADA0   classic_bike  2023-01-26 10:53:44
# 1        AE02E1FF7E264874   classic_bike  2023-01-04 11:51:54
# 2        D3F9A2A71AD244C6   classic_bike  2023-01-04 17:26:48
# 3        3D48C6F33AFEF329   classic_bike  2023-01-04 08:31:11
# 4        4865926C3D97BA01  electric_bike  2023-01-03 22:15:34
# ...                   ...            ...                  ...
# 1855196  E4317A223A047233   classic_bike  2023-01-02 17:29:12
# 1855197  ABE3E9D3F081A13E   classic_bike  2023-01-03 17:47:28
# 1855198  8F1B225FFE447DD6   classic_bike  2023-01-12 20:18:52
# 1855199  A631B3D94A1BBE4F   classic_bike  2023-01-13 00:16:36
# 1855200  719C2F8C8D500BA2  electric_bike  2023-01-15 15:57:48
#
# ...

# %%
citi_bike_jan = pd.read_csv('Resources/202201-citibike-tripdata.csv')
citi_bike_feb = pd.read_csv('Resources/202202-citibike-tripdata.csv')
citi_bike_mar = pd.read_csv('Resources/202203-citibike-tripdata.csv')
citi_bike_apr = pd.read_csv('Resources/202204-citibike-tripdata.csv')
citi_bike_may = pd.read_csv('Resources/202205-citibike-tripdata.csv')
citi_bike_jun = pd.read_csv('Resources/202206-citibike-tripdata.csv')
citi_bike_jul = pd.read_csv('Resources/202207-citibike-tripdata.csv')
citi_bike_aug = pd.read_csv('Resources/202208-citibike-tripdata.csv')
citi_bike_sep = pd.read_csv('Resources/202209-citibike-tripdata.csv')
citi_bike_oct = pd.read_csv('Resources/202210-citibike-tripdata.csv')
citi_bike_nov = pd.read_csv('Resources/202211-citibike-tripdata.csv')
citi_bike_dec = pd.read_csv('Resources/202212-citibike-tripdata.csv')
# Out:
# C:\Users\yaber\AppData\Local\Temp\ipykernel_12364\3629666873.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citi_bike_jan = pd.read_csv('Resources/202201-citibike-tripdata.csv')
# C:\Users\yaber\AppData\Local\Temp\ipykernel_12364\3629666873.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citi_bike_feb = pd.read_csv('Resources/202202-citibike-tripdata.csv')
# C:\Users\yaber\AppData\Local\Temp\ipykernel_12364\3629666873.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citi_bike_mar = pd.read_csv('Resources/202203-citibike-tripdata.csv')
# C:\Users\yaber\AppData\Local\Temp\ipykernel_12364\3629666873.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citi_bike_apr = pd.read_csv('Resources/202204-citibike-tripdata.csv')
# ...

# %%
citi_bike_2022 = [citi_bike_jan, citi_bike_feb, citi_bike_mar, citi_bike_apr, citi_bike_may, citi_bike_jun,
                  citi_bike_jul, citi_bike_aug, citi_bike_sep, citi_bike_oct, citi_bike_nov, citi_bike_dec]

# %%
citi_bike_2022_merged = pd.concat(citi_bike_2022, axis=0)

citi_bike_2022_merged
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        55262E4365A955A2   classic_bike  2022-01-18 08:23:52
# 1        D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22
# 2        D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32
# 3        E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47
# 4        2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06
# ...                   ...            ...                  ...
# 1649647  CB2EE50F60A58C7B   classic_bike  2022-12-12 08:38:46
# 1649648  3C0DF3280FEB1350   classic_bike  2022-12-12 13:06:32
# 1649649  B916E63B630D5020   classic_bike  2022-12-18 01:15:22
# 1649650  21EAC007BE7D4161   classic_bike  2022-12-08 23:09:54
# 1649651  538408C4A16F4415  electric_bike  2022-12-21 07:26:14
#
#                     ended_at                 start_station_name  \
# 0        2022-01-18 08:28:18            Boerum Pl\t& Pacific St
# 1        2022-01-21 09:05:44                    E 12 St & Ave C
# ...

# %%
len(citi_bike_2022_merged.index)
# Out:
# 30689921

# %%
# citi_bike_2022_merged.to_csv('citi_bike_data_2022.csv', index=False)

# %%
citi_bike_2022Q4 = [citi_bike_oct, citi_bike_nov, citi_bike_dec]

# %%
citi_bike_2022Q4_merged = pd.concat(citi_bike_2022Q4, axis=0)

citi_bike_2022Q4_merged
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        2CF35A89B21C6E3C   classic_bike  2022-10-24 14:30:25
# 1        291CC2C6D361C2DA   classic_bike  2022-10-30 03:53:38
# 2        80192DC8429B07EE   classic_bike  2022-10-08 15:03:06
# 3        D214E550C317C65E   classic_bike  2022-10-18 08:32:04
# 4        2D23E8BAE75AA184   classic_bike  2022-10-26 08:00:40
# ...                   ...            ...                  ...
# 1649647  CB2EE50F60A58C7B   classic_bike  2022-12-12 08:38:46
# 1649648  3C0DF3280FEB1350   classic_bike  2022-12-12 13:06:32
# 1649649  B916E63B630D5020   classic_bike  2022-12-18 01:15:22
# 1649650  21EAC007BE7D4161   classic_bike  2022-12-08 23:09:54
# 1649651  538408C4A16F4415  electric_bike  2022-12-21 07:26:14
#
#                     ended_at                 start_station_name  \
# 0        2022-10-24 14:37:35        St. Nicholas Ave & W 126 St
# 1        2022-10-30 03:57:57         Stuyvesant Ave & Gates Ave
# ...

# %%
# citi_bike_2022Q4_merged.to_csv('citi_bike_2022Q4.csv', index=False)
